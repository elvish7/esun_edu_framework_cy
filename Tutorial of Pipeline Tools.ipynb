# %% [markdown]
# # 資料前處理
#
# 使用我們的common/ETLBase.py的ProcessBase物件進行處理模組的參數與函數定義。
#
# ---
#
#
# #### 3.1) 資料前處理工具: ETLBase 簡介
#
# 為了能讓資料轉換為能夠輸入模型的形式，實驗建置過程中，往往會需要耗費許多的心力來進行資料的前處理，而對於不同的模型版本，又有可能會有相應的不一樣的前處理方式，隨著實驗的增加，前處理的程式也相應得變得越來越難以維護。另外，建立前處理程式的過程中，往往涉及到大量冗長的資料轉換，因此在開發過程中也容易因資料轉換而耽誤了開發時程。
#
# 因此，我們提供前處理工具（`ETLBase`)，希望不只讓前處理程式更易於理解，也可以開發更快速。此前處理工具可以透過視覺化的方式，將前處理過程中的模塊、模塊的輸入、輸出，以及模塊之間的串連方式，以[有向圖(DAG)](https://zh.wikipedia.org/wiki/File:Tred-G.svg)的方式呈現，讓前處理的步驟與邏輯可以一目了然。另外，此工具也加入了資料中繼檔暫存功能，讓前處理過程中的中間產物，可以被以檔案的方式儲存起來，讓後續使用此中間產物的處理模塊可以快速載入，進行後續模塊的調整。
#
# 此工具使用方式為繼承我們的`common/ETLBase`中的`ProcessBase`類別，並覆蓋其中的函數，達到規格化地定義前處理模塊、模塊串接方式、前處理輸入輸入參數的功能。以下我們將對此工具的使用方式進行簡單說明，詳細操作方式請參考[Jupyter Notebook - Tutorial of Pipeline Tools.ipynb](https://github.com/udothemath/edu_framework/blob/enhance_preprocess_module/Tutorial%20of%20Pipeline%20Tools.ipynb)。

# %% [markdown]
# #### 3.2) 前處理定義方式
#
# ---
#
# 假設前處理涉及兩個參數a,b，我們想要讓c = a + b, d = a + c, e = d + d，最後輸出三行的pandas.DataFrame，每一行的內容為e，我們可以以下面方式進行串接:

# %% [markdown]
# ##### 一般使用模式:

# %%
from common.ETLBase import ProcessBase
class PreProcess(ProcessBase):
    # Step 1: 模塊名稱定義
    def module_name(self):
        return "tutorial_preprocess"
    # Step 2.1: 輸入參數定義    
    def inputs(self):
        return [
            'a', 
            'b'
        ]
    # Step 2.2: 輸出參數定義 
    def outputs(self):
        return ['table'] 
    
    # Step 3: 模塊定義 
    def define_functions(self, pipe):
        import numpy as np
        import pandas as pd 
        @pipe._func_
        def plus_a_b(a,b):
            return a+b
             
        @pipe._func_
        def repeat(a,b=3):
            return np.repeat(a,b)
        
        @pipe._func_
        def to_dataframe(seq):
            return pd.DataFrame(seq)
        
    # Step 4: 串接方式定義
    def connections(self, **kargs):
        conns = [
            'c = plus_a_b(a,b)', 
            'd = plus_a_b(a,c)', 
            'e = plus_a_b(d,d)',
            'e_array = repeat(e)',
            'table = to_dataframe(e_array)'
        ]
        return conns

# %%
preprocess = PreProcess() 
preprocess.config(a=1, b=2, verbose=True)
# Out:
# packages in _define_operators: []
# [Connect] a,b=collect_inputs_for_tutorial_preprocess(a=a,b=b)
# [Connect] c=plus_a_b(a,b)
# [Connect] d=plus_a_b(a,c)
# [Connect] e=plus_a_b(d,d)
# [Connect] e_array=repeat(e)
# [Connect] table=to_dataframe(e_array)

# %%
preprocess.pipe.view(summary=False, option='all')
# Out:
# Warning: using box for unknown shape cylinder

# %%
preprocess.pipe.e_array.get(verbose=True)
# Out:
# [RUN] process of "gather"
# [COMPLETE] gather
# [RUN] process of "gather[0]"
# [COMPLETE] gather[0]
# [REMOVE] result of "gather"
# [LOAD] result of "gather[0]"
# [RUN] process of "gather"
# [COMPLETE] gather
# [RUN] process of "gather[1]"
# [COMPLETE] gather[1]
# [REMOVE] result of "gather"
# [RUN] process of "plus_a_b"
# [COMPLETE] plus_a_b
# [REMOVE] result of "gather[0]"
# [REMOVE] result of "gather[1]"
# [RUN] process of "plus_a_b"
# [COMPLETE] plus_a_b
# [REMOVE] result of "gather[0]"
# [REMOVE] result of "plus_a_b"
# [LOAD] result of "plus_a_b"
# [RUN] process of "plus_a_b"
# [COMPLETE] plus_a_b
# [REMOVE] result of "plus_a_b"
# [REMOVE] result of "plus_a_b"
# [RUN] process of "repeat"
# [COMPLETE] repeat
# [REMOVE] result of "plus_a_b"
# array([8, 8, 8])

# %% [markdown]
# ##### 使用.py載入模塊與串接設定

# %%
from common.ETLBase import ProcessBase
from common.process_compiler import block_str_generator

class PreProcess(ProcessBase):
    # Step 1: 模塊名稱定義
    def module_name(self):
        return "tutorial_preprocess"
    # Step 2.1: 輸入參數定義    
    def inputs(self):
        return [
            'a', 
            'b'
        ]
    # Step 2.2: 輸出參數定義 
    def outputs(self):
        return ['table'] 
    
    # Step 3: 模塊定義 
    def packages(self):
        return 'tutorial.ops'
        
    # Step 4: 串接方式定義
    def connections(self, **kargs):
        conns = block_str_generator('tutorial/connect.py')
        return conns

# %%
preprocess = PreProcess() 
preprocess.config(a=1, b=2, verbose=True)
# Out:
# packages in _define_operators: tutorial.ops
# [Connect] a,b=collect_inputs_for_tutorial_preprocess(a=a,b=b)
# [Connect] c=plus_a_b(a,b)
# [Connect] d=plus_a_b(a,c)
# [Connect] e=plus_a_b(d,d)
# [Connect] e_array=repeat(e)
# [Connect] table=to_dataframe(e_array)

# %%
preprocess.pipe.view(summary=False)
# Out:
# Warning: using box for unknown shape cylinder

# %%
preprocess.pipe.view_dependency('c', summary=False)
# Out:
# Warning: using box for unknown shape cylinder

# %%
preprocess.pipe.table.get(verbose=True)
# Out:
# [RUN] process of "gather"
# [COMPLETE] gather
# [RUN] process of "gather[0]"
# [COMPLETE] gather[0]
# [LOAD] result of "gather[0]"
# [LOAD] result of "gather"
# [RUN] process of "gather[1]"
# [COMPLETE] gather[1]
# [REMOVE] result of "gather"
# [RUN] process of "plus_a_b"
# [COMPLETE] plus_a_b
# [REMOVE] result of "gather[1]"
# [RUN] process of "plus_a_b"
# [COMPLETE] plus_a_b
# [REMOVE] result of "gather[0]"
# [REMOVE] result of "plus_a_b"
# [LOAD] result of "plus_a_b"
# [RUN] process of "plus_a_b"
# [COMPLETE] plus_a_b
# [REMOVE] result of "plus_a_b"
# [REMOVE] result of "plus_a_b"
# [RUN] process of "repeat"
# [COMPLETE] repeat
# [REMOVE] result of "plus_a_b"
# [RUN] process of "to_dataframe"
# [COMPLETE] to_dataframe
# [REMOVE] result of "repeat"
#    0
# 0  8
# 1  8
# 2  8

# %% [markdown]
# ##### 中繼檔暫存功能使用

# %%
from common.ETLBase import ProcessBase
from common.process_compiler import block_str_generator

class PreProcess(ProcessBase):
    # Step 1: 模塊名稱定義
    def module_name(self):
        return "tutorial_preprocess"
    # Step 2.1: 輸入參數定義    
    def inputs(self):
        return [
            'a', 
            'b'
        ]
    # Step 2.2: 輸出參數定義 
    def outputs(self):
        return ['table'] 
    
    # Step 3: 模塊定義 
    def packages(self):
        return ['tutorial.ops']
        
    # Step 4: 串接方式定義
    def connections(self, **kargs):
        conns = [
            'c = plus_a_b(a=a,b=b)', 
            'd = plus_a_b(a,c)', 
            'e = plus_a_b(d,d)',
            ('e_array = repeat(e)','e_array.npy'),
            ('table = to_dataframe(e_array)','table.feather')
        ]
        return conns

# %%
preprocess = PreProcess(save_tmp=True)  
preprocess.config(a=1, b=2, verbose=True)
# Out:
# packages in _define_operators: ['tutorial.ops']
# [Connect] a,b=collect_inputs_for_tutorial_preprocess(a=a,b=b)
# [Connect] c=plus_a_b(a=a,b=b)
# [Connect] d=plus_a_b(a,c)
# [Connect] e=plus_a_b(d,d)
# [Connect] e_array=repeat(e) [Result Dir] ['data/tutorial_preprocess/tmp/e_array.npy']
# [Connect] table=to_dataframe(e_array) [Result Dir] ['data/tutorial_preprocess/tmp/table.feather']

# %%
preprocess.pipe.table.get(verbose=True, load_tmp=True)
# Out:
# [LOAD] result of "repeat"
#  from data/tutorial_preprocess/tmp/e_array.npy
# [RUN] process of "to_dataframe"
# [COMPLETE] to_dataframe
# [REMOVE] result of "repeat"
# [SAVE] result of "to_dataframe"
#  as data/tutorial_preprocess/tmp/table.feather
# [SAVE] result of "to_dataframe"
# in memory
#    0
# 0  8
# 1  8
# 2  8

# %% [markdown]
# # Experiment example (ex4)

# %%
from experiments.ex4.preprocess.config import PreProcess
import os

preprocess = PreProcess(save_tmp=True) 

origin_path = 'data/source'
preprocess.config(
    chid_file=os.path.join(origin_path, 'sample_chid.txt'), 
    cdtx_file=os.path.join(origin_path, 'sample_zip_if_cca_cdtx0001_hist.csv'), 
    cust_f_file=os.path.join(origin_path, 'sample_zip_if_cca_cust_f.csv'),
    category_cols=['chid', 'bnsfg', 'iterm', 'mcc', 'scity'], 
    sparse_feat=['chid', 'bnsfg', 'iterm', 'mcc', 'scity'], 
    numeric_cols=['bnspt', 'timestamp_0', 'timestamp_1', 'objam'],
    dense_feat=['bnspt', 'timestamp_0', 'timestamp_1', 'objam'],
    cust_category_cols=['chid', 'masts', 'educd', 'trdtp', 'poscd'], 
    cust_numeric_cols=['slam', 'first_mob', 'constant_change', 'sum_l2_ind',
                  'sum_u2_ind', 'constant_l2_ind', 'constant_u4_ind',
                  'growth_rate', 'monotone_down', 'monotone_up', 'data_dt'],
    target_cols=['chid', 'data_dt', 'objam_sum', 'objam_mean', 'trans_count', 'objam_mean_M3'], 
    USE_CHID=True, 
    time_column_data_dt='data_dt', 
    time_column_csmdt='csmdt', 
    result_column_timestamp_1='timestamp_1', 
    result_column_timestamp_0='timestamp_0', 
    result_column_timestamp='timestamp', 
    LEFT='left', 
    INNER='inner', 
    n_sample=50, 
    window_size=120,
    test_size=2
)
# Out:
# packages in _define_operators: ['experiments.ex4.preprocess.ops']
# [Connect] chid_file,cdtx_file,cust_f_file,category_cols,sparse_feat,numeric_cols,dense_feat,cust_category_cols,cust_numeric_cols,target_cols,USE_CHID,time_column_data_dt,time_column_csmdt,result_column_timestamp_1,result_column_timestamp_0,result_column_timestamp,LEFT,INNER,n_sample,window_size,test_size=collect_inputs_for_ex4_preprocess(chid_file=chid_file,cdtx_file=cdtx_file,cust_f_file=cust_f_file,category_cols=category_cols,sparse_feat=sparse_feat,numeric_cols=numeric_cols,dense_feat=dense_feat,cust_category_cols=cust_category_cols,cust_numeric_cols=cust_numeric_cols,target_cols=target_cols,USE_CHID=USE_CHID,time_column_data_dt=time_column_data_dt,time_column_csmdt=time_column_csmdt,result_column_timestamp_1=result_column_timestamp_1,result_column_timestamp_0=result_column_timestamp_0,result_column_timestamp=result_column_timestamp,LEFT=LEFT,INNER=INNER,n_sample=n_sample,window_size=window_size,test_size=test_size)
# [Connect] sparse_dense_setting_generator=create_sparse_dense_setting_generator(category_cols=category_cols,sparse_feat=sparse_feat,numeric_cols=numeric_cols,dense_feat=dense_feat,USE_CHID=USE_CHID)
# [Connect] chids=load_chids(chid_file=chid_file)
# [Connect] sampled_chids=sample_chids(chids,n_sample=n_sample) [Result Dir] ['data/ex4_preprocess/tmp/sampled_chids.npy']
# [Connect] chid_to_nid_map=build_chid_to_nid_map(sampled_chids)
# [Connect] df_cdtx=load_cdtx(sampled_chids,cdtx_file=cdtx_file)
# [Connect] df_cdtx=convert_uid_to_nid(df_cdtx,chid_to_nid_map)
# [Connect] df_cdtx=add_month(df_cdtx) [Result Dir] ['data/ex4_preprocess/tmp/df_cdtx.feather']
# [Connect] df_full_y_sum=make_chid_x_month_table(df_cdtx)
# [Connect] df_cdtx_monthly_objam=calculate_monthly_target(df_cdtx)
# [Connect] df_full_y_sum=merge_with_another_table(df_full_y_sum,df_cdtx_monthly_objam,join_method=LEFT)
# [Connect] df_cust_f=load_cust_f(sampled_chids,cust_f_file=cust_f_file)
# [Connect] df_cust_f=convert_uid_to_nid(df_cust_f,chid_to_nid_map) [Result Dir] ['data/ex4_preprocess/tmp/df_cust_f.feather']
# [Connect] df_full_y_sum=merge_with_another_table(df_full_y_sum,df_cust_f,join_method=INNER)
# [Connect] df_full_y_sum=add_mean_of_previous_two_months(df_full_y_sum)
# [Connect] df_full_y_sum=cast_time_column_to_np_datatime64(df_full_y_sum,time_column=time_column_data_dt)
# [Connect] df_cdtx=cast_time_column_to_np_datatime64(df_cdtx,time_column=time_column_csmdt)
# [Connect] df_cdtx=add_duration_since_20180101(df_cdtx,time_column=time_column_csmdt,result_column=result_column_timestamp_1)
# [Connect] df_cdtx=add_duration_since_last_trans(df_cdtx,time_column=time_column_csmdt,result_column=result_column_timestamp_0)
# [Connect] df_input,feature_map=extract_feature_cols_and_encode_categoricals(df_cdtx,numeric_cols=numeric_cols,category_cols=category_cols) [Result Dir] ['data/ex4_preprocess/tmp/df_input.feather', 'data/ex4_preprocess/tmp/feature_map.npy']
# [Connect] df_feat_input,cust_feature_map=extract_feature_cols_and_encode_categoricals(df_cust_f,numeric_cols=cust_numeric_cols,category_cols=cust_category_cols) [Result Dir] ['data/ex4_preprocess/tmp/df_feat_input.feather', 'data/ex4_preprocess/tmp/cust_feature_map.npy']
# [Connect] df_feat_input=cast_time_column_to_np_datatime64(df_feat_input,time_column=time_column_data_dt)
# [Connect] df_feat_input=add_duration_since_20180101(df_feat_input,time_column=time_column_data_dt,result_column=result_column_timestamp) [Result Dir] ['data/ex4_preprocess/tmp/df_feat_input.2.feather']
# [Connect] df_y=extract_target_columns(df_full_y_sum,target_cols=target_cols)
# [Connect] df_y=add_duration_since_20180101(df_y,time_column=time_column_data_dt,result_column=result_column_timestamp) [Result Dir] ['data/ex4_preprocess/tmp/df_y.feather']
# [Connect] x_train,x_test,f_train,f_test,y_train,y_test=split_data(df_input,df_feat_input,df_y,window_size=window_size,test_size=test_size) [Result Dir] ['data/ex4_preprocess/tmp/x_train.npy', 'data/ex4_preprocess/tmp/x_test.npy', 'data/ex4_preprocess/tmp/f_train.npy', 'data/ex4_preprocess/tmp/f_test.npy', 'data/ex4_preprocess/tmp/y_train.npy', 'data/ex4_preprocess/tmp/y_test.npy']
# [Connect] y_train,y_test,y_columns=add_objam_mean_M3_diff_as_new_target(df_y,y_train,y_test) [Result Dir] ['data/ex4_preprocess/tmp/y_train.npy', 'data/ex4_preprocess/tmp/y_test.npy', 'data/ex4_preprocess/tmp/y_columns.npy']
# [Connect] columns=extract_x_f_y_columns(df_input,df_feat_input,y_columns)
# [Connect] sparse_dims,sparse_index,dense_dims,dense_index=sparse_dense_setting_generating_process(sparse_dense_setting_generator,feature_map,chid_to_nid_map)
# [Connect] x_train_sparse,x_train_dense,x_test_sparse,x_test_dense=ProcessX.process(x_train,x_test,sparse_index,dense_index) [Result Dir] ['data/ex4_preprocess/tmp/x_train_sparse.npy', 'data/ex4_preprocess/tmp/x_train_dense.npy', 'data/ex4_preprocess/tmp/x_test_sparse.npy', 'data/ex4_preprocess/tmp/x_test_dense.npy']
# [Connect] train_objmean,train_tscnt,train_label_0,test_objmean,test_tscnt,test_label_0=ProcessY.process(y_train,y_test,columns) [Result Dir] ['data/ex4_preprocess/tmp/train_objmean.npy', 'data/ex4_preprocess/tmp/train_tscnt.npy', 'data/ex4_preprocess/tmp/train_label_0.npy', 'data/ex4_preprocess/tmp/test_objmean.npy', 'data/ex4_preprocess/tmp/test_tscnt.npy', 'data/ex4_preprocess/tmp/test_label_0.npy']
# [Connect] train_dataset=build_TensorDataset(x_train_dense,x_train_sparse,train_objmean,train_tscnt,train_label_0)
# [Connect] test_dataset=build_TensorDataset(x_test_dense,x_test_sparse,test_objmean,test_tscnt,test_label_0)

# %%
preprocess.pipe.view(summary=False)
# Out:
# Warning: using box for unknown shape cylinder

# %%
preprocess.pipe.USE_CHID.get()
# Out:
# True

# %% [markdown]
# preprocess.pipe.train_dataset.get(verbose=True, load_tmp=True)
#
# preprocess.pipe.train_dataset.get(verbose=True, load_tmp=True)
#
# preprocess.pipe.dense_dims.get(verbose=True, load_tmp=True)
#
# preprocess.pipe.sparse_dims.get(verbose=True, load_tmp=True)
#
# preprocess.pipe.test_objmean.get(verbose=True, load_tmp=True)
#
# preprocess.pipe.test_tscnt.get(verbose=True, load_tmp=True)
#
# preprocess.pipe.test_label_0.get(verbose=True, load_tmp=True)
